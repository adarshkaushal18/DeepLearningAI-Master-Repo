# %% [markdown]
# # L6: Building Your Crew for Production

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Creating a new project

# %%
! crewai create crew new_project --provider openai
# Out:
# Creating folder new_project...
#   - Created new_project/.gitignore
#   - Created new_project/pyproject.toml
#   - Created new_project/README.md
#   - Created new_project/src/new_project/__init__.py
#   - Created new_project/src/new_project/main.py
#   - Created new_project/src/new_project/crew.py
#   - Created new_project/src/new_project/tools/custom_tool.py
#   - Created new_project/src/new_project/tools/__init__.py
#   - Created new_project/src/new_project/config/agents.yaml
#   - Created new_project/src/new_project/config/tasks.yaml
# Crew new_project created successfully!

# %% [markdown]
# ## Setting up the Environment

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note</code>:</b> The following line might take a few minutes to finish.</p>

# %%
! cd new_project && crewai install
# Out:
# Using CPython 3.11.9 interpreter at: /usr/local/bin/python
# Creating virtual environment at: .venv
# Resolved 211 packages in 1.94s
# Building new-project @ file:///home/jovyan/work/L13/new_project
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# pydantic   ------------------------------     0 B/434.36 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------     0 B/357.76 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------     0 B/357.76 KiB
# rpds-py    ------------------------------     0 B/374.88 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------     0 B/357.76 KiB
# rpds-py    ------------------------------     0 B/374.88 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------     0 B/357.76 KiB
# rpds-py    ------------------------------     0 B/374.88 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------     0 B/357.76 KiB
# rpds-py    ------------------------------     0 B/374.88 KiB
# pydantic   ------------------------------     0 B/434.36 KiB
# watchfiles ------------------------------     0 B/442.52 KiB
# cffi       ------------------------------     0 B/456.29 KiB
# pytz       ------------------------------     0 B/497.29 KiB
# mpmath     ------------------------------     0 B/523.63 KiB
# huggingface-hub ------------------------------     0 B/545.69 KiB
# greenlet   ------------------------------     0 B/571.78 KiB
# chromadb   ------------------------------     0 B/613.62 KiB
# pyyaml     ------------------------------     0 B/745.07 KiB
# pygments   ------------------------------ 14.88 KiB/1.17 MiB
# kubernetes ------------------------------     0 B/1.85 MiB
# pydantic-core ------------------------------     0 B/1.91 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 46.92 KiB/357.76 KiB
# rpds-py    ------------------------------ 46.91 KiB/374.88 KiB
# prompt-toolkit ------------------------------ 30.88 KiB/378.72 KiB
# langchain-core ------------------------------ 6.60 KiB/432.43 KiB
# pydantic   ------------------------------ 30.88 KiB/434.36 KiB
# watchfiles ------------------------------ 14.91 KiB/442.52 KiB
# httptools  ------------------------------ 14.91 KiB/449.01 KiB
# cffi       ------------------------------ 62.78 KiB/456.29 KiB
# pytz       ------------------------------ 30.88 KiB/497.29 KiB
# mpmath     ------------------------------ 46.84 KiB/523.63 KiB
# huggingface-hub ------------------------------ 30.88 KiB/545.69 KiB
# greenlet   ------------------------------ 30.92 KiB/571.78 KiB
# chromadb   ------------------------------ 30.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 14.92 KiB/634.88 KiB
# pyvis      ------------------------------ 14.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 30.88 KiB/745.07 KiB
# openai     ------------------------------ 16.00 KiB/746.46 KiB
# regex      ------------------------------ 16.00 KiB/774.15 KiB
# ipython    ------------------------------ 15.89 KiB/812.37 KiB
# langchain  ------------------------------ 14.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 14.88 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 62.92 KiB/357.76 KiB
# rpds-py    ------------------------------ 174.11 KiB/374.88 KiB
# prompt-toolkit ------------------------------ 46.88 KiB/378.72 KiB
# langchain-core ------------------------------ 30.88 KiB/432.43 KiB
# pydantic   ------------------------------ 62.88 KiB/434.36 KiB
# watchfiles ------------------------------ 139.60 KiB/442.52 KiB
# httptools  ------------------------------ 158.91 KiB/449.01 KiB
# cffi       ------------------------------ 190.34 KiB/456.29 KiB
# pytz       ------------------------------ 46.88 KiB/497.29 KiB
# mpmath     ------------------------------ 142.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 62.88 KiB/545.69 KiB
# greenlet   ------------------------------ 171.23 KiB/571.78 KiB
# chromadb   ------------------------------ 62.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 14.92 KiB/634.88 KiB
# pyvis      ------------------------------ 174.84 KiB/738.32 KiB
# pyyaml     ------------------------------ 189.64 KiB/745.07 KiB
# openai     ------------------------------ 48.00 KiB/746.46 KiB
# regex      ------------------------------ 142.69 KiB/774.15 KiB
# ipython    ------------------------------ 15.89 KiB/812.37 KiB
# langchain  ------------------------------ 14.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 159.37 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 78.92 KiB/357.76 KiB
# rpds-py    ------------------------------ 270.11 KiB/374.88 KiB
# prompt-toolkit ------------------------------ 62.88 KiB/378.72 KiB
# langchain-core ------------------------------ 46.88 KiB/432.43 KiB
# pydantic   ------------------------------ 156.33 KiB/434.36 KiB
# watchfiles ------------------------------ 219.60 KiB/442.52 KiB
# httptools  ------------------------------ 254.91 KiB/449.01 KiB
# cffi       ------------------------------ 270.34 KiB/456.29 KiB
# pytz       ------------------------------ 46.88 KiB/497.29 KiB
# mpmath     ------------------------------ 238.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 248.54 KiB/545.69 KiB
# greenlet   ------------------------------ 253.68 KiB/571.78 KiB
# chromadb   ------------------------------ 78.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 46.92 KiB/634.88 KiB
# pyvis      ------------------------------ 270.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 285.64 KiB/745.07 KiB
# openai     ------------------------------ 62.66 KiB/746.46 KiB
# regex      ------------------------------ 222.58 KiB/774.15 KiB
# ipython    ------------------------------ 111.17 KiB/812.37 KiB
# langchain  ------------------------------ 30.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 258.54 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠙ Preparing packages... (0/204)
# crewai     ------------------------------ 94.92 KiB/357.76 KiB
# rpds-py    ------------------------------ 334.11 KiB/374.88 KiB
# prompt-toolkit ------------------------------ 62.88 KiB/378.72 KiB
# langchain-core ------------------------------ 78.88 KiB/432.43 KiB
# pydantic   ------------------------------ 245.21 KiB/434.36 KiB
# watchfiles ------------------------------ 287.60 KiB/442.52 KiB
# httptools  ------------------------------ 312.09 KiB/449.01 KiB
# cffi       ------------------------------ 334.34 KiB/456.29 KiB
# pytz       ------------------------------ 62.88 KiB/497.29 KiB
# mpmath     ------------------------------ 366.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 287.11 KiB/545.69 KiB
# greenlet   ------------------------------ 333.68 KiB/571.78 KiB
# chromadb   ------------------------------ 350.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 62.92 KiB/634.88 KiB
# pyvis      ------------------------------ 334.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 365.64 KiB/745.07 KiB
# openai     ------------------------------ 78.66 KiB/746.46 KiB
# regex      ------------------------------ 271.14 KiB/774.15 KiB
# ipython    ------------------------------ 239.17 KiB/812.37 KiB
# langchain  ------------------------------ 30.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 322.31 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# crewai     ------------------------------ 110.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 78.88 KiB/378.72 KiB
# langchain-core ------------------------------ 110.88 KiB/432.43 KiB
# pydantic   ------------------------------ 268.33 KiB/434.36 KiB
# watchfiles ------------------------------ 335.60 KiB/442.52 KiB
# httptools  ------------------------------ 353.84 KiB/449.01 KiB
# cffi       ------------------------------ 378.92 KiB/456.29 KiB
# pytz       ------------------------------ 108.46 KiB/497.29 KiB
# mpmath     ------------------------------ 398.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 302.11 KiB/545.69 KiB
# greenlet   ------------------------------ 397.47 KiB/571.78 KiB
# chromadb   ------------------------------ 366.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 62.92 KiB/634.88 KiB
# pyvis      ------------------------------ 382.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 397.64 KiB/745.07 KiB
# openai     ------------------------------ 94.56 KiB/746.46 KiB
# regex      ------------------------------ 334.69 KiB/774.15 KiB
# ipython    ------------------------------ 287.17 KiB/812.37 KiB
# langchain  ------------------------------ 30.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 366.88 KiB/1.14 MiB
# pygments   ------------------------------ 350.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------     0 B/354.49 KiB
# crewai     ------------------------------ 110.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 94.88 KiB/378.72 KiB
# langchain-core ------------------------------ 126.88 KiB/432.43 KiB
# pydantic   ------------------------------ 284.33 KiB/434.36 KiB
# watchfiles ------------------------------ 383.60 KiB/442.52 KiB
# httptools  ------------------------------ 385.84 KiB/449.01 KiB
# cffi       ------------------------------ 414.34 KiB/456.29 KiB
# pytz       ------------------------------ 108.46 KiB/497.29 KiB
# mpmath     ------------------------------ 414.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 367.89 KiB/545.69 KiB
# greenlet   ------------------------------ 413.68 KiB/571.78 KiB
# chromadb   ------------------------------ 366.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 78.81 KiB/634.88 KiB
# pyvis      ------------------------------ 430.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 417.37 KiB/745.07 KiB
# openai     ------------------------------ 94.56 KiB/746.46 KiB
# regex      ------------------------------ 366.69 KiB/774.15 KiB
# ipython    ------------------------------ 307.92 KiB/812.37 KiB
# langchain  ------------------------------ 30.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 392.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 24.54 KiB/354.49 KiB
# crewai     ------------------------------ 126.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 110.88 KiB/378.72 KiB
# langchain-core ------------------------------ 152.28 KiB/432.43 KiB
# pydantic   ------------------------------ 316.33 KiB/434.36 KiB
# httptools  ------------------------------ 449.01 KiB/449.01 KiB
# cffi       ------------------------------ 456.29 KiB/456.29 KiB
# pytz       ------------------------------ 124.46 KiB/497.29 KiB
# mpmath     ------------------------------ 494.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 393.90 KiB/545.69 KiB
# greenlet   ------------------------------ 461.68 KiB/571.78 KiB
# chromadb   ------------------------------ 382.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.92 KiB/634.88 KiB
# pyvis      ------------------------------ 494.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 477.64 KiB/745.07 KiB
# openai     ------------------------------ 126.45 KiB/746.46 KiB
# regex      ------------------------------ 430.69 KiB/774.15 KiB
# ipython    ------------------------------ 351.17 KiB/812.37 KiB
# langchain  ------------------------------ 46.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 456.33 KiB/1.14 MiB
# pygments   ------------------------------ 414.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 24.54 KiB/354.49 KiB
# crewai     ------------------------------ 126.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 110.88 KiB/378.72 KiB
# langchain-core ------------------------------ 168.28 KiB/432.43 KiB
# pydantic   ------------------------------ 316.33 KiB/434.36 KiB
# httptools  ------------------------------ 449.01 KiB/449.01 KiB
# pytz       ------------------------------ 124.46 KiB/497.29 KiB
# mpmath     ------------------------------ 510.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 393.90 KiB/545.69 KiB
# greenlet   ------------------------------ 461.68 KiB/571.78 KiB
# chromadb   ------------------------------ 398.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.92 KiB/634.88 KiB
# pyvis      ------------------------------ 510.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 493.64 KiB/745.07 KiB
# openai     ------------------------------ 126.45 KiB/746.46 KiB
# regex      ------------------------------ 446.69 KiB/774.15 KiB
# ipython    ------------------------------ 367.17 KiB/812.37 KiB
# langchain  ------------------------------ 46.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 456.56 KiB/1.14 MiB
# pygments   ------------------------------ 430.12 KiB/1.17 MiB
# jedi       ------------------------------ 223.16 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# langsmith  ------------------------------ 24.54 KiB/354.49 KiB
# crewai     ------------------------------ 126.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 110.88 KiB/378.72 KiB
# langchain-core ------------------------------ 168.28 KiB/432.43 KiB
# pydantic   ------------------------------ 316.33 KiB/434.36 KiB
# pytz       ------------------------------ 124.46 KiB/497.29 KiB
# mpmath     ------------------------------ 510.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 393.90 KiB/545.69 KiB
# greenlet   ------------------------------ 461.68 KiB/571.78 KiB
# chromadb   ------------------------------ 398.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.92 KiB/634.88 KiB
# pyvis      ------------------------------ 510.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 493.64 KiB/745.07 KiB
# openai     ------------------------------ 126.45 KiB/746.46 KiB
# regex      ------------------------------ 446.69 KiB/774.15 KiB
# ipython    ------------------------------ 367.17 KiB/812.37 KiB
# langchain  ------------------------------ 46.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 456.56 KiB/1.14 MiB
# pygments   ------------------------------ 430.12 KiB/1.17 MiB
# jedi       ------------------------------ 223.16 KiB/1.50 MiB
# networkx   ------------------------------ 270.88 KiB/1.64 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# tzdata     ------------------------------     0 B/339.69 KiB
# yarl       ------------------------------     0 B/340.80 KiB
# jiter      ------------------------------     0 B/343.92 KiB
# langsmith  ------------------------------ 56.54 KiB/354.49 KiB
# crewai     ------------------------------ 126.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 126.88 KiB/378.72 KiB
# langchain-core ------------------------------ 184.28 KiB/432.43 KiB
# pydantic   ------------------------------ 364.33 KiB/434.36 KiB
# pytz       ------------------------------ 124.46 KiB/497.29 KiB
# mpmath     ------------------------------ 510.68 KiB/523.63 KiB
# huggingface-hub ------------------------------ 393.90 KiB/545.69 KiB
# greenlet   ------------------------------ 461.68 KiB/571.78 KiB
# chromadb   ------------------------------ 398.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 94.92 KiB/634.88 KiB
# pyvis      ------------------------------ 526.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 509.64 KiB/745.07 KiB
# openai     ------------------------------ 142.66 KiB/746.46 KiB
# regex      ------------------------------ 462.69 KiB/774.15 KiB
# ipython    ------------------------------ 377.67 KiB/812.37 KiB
# langchain  ------------------------------ 46.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 472.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# tzdata     ------------------------------ 16.00 KiB/339.69 KiB
# yarl       ------------------------------ 16.00 KiB/340.80 KiB
# jiter      ------------------------------ 20.02 KiB/343.92 KiB
# langsmith  ------------------------------ 112.00 KiB/354.49 KiB
# crewai     ------------------------------ 126.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 142.88 KiB/378.72 KiB
# langchain-core ------------------------------ 200.28 KiB/432.43 KiB
# pydantic   ------------------------------ 412.33 KiB/434.36 KiB
# pytz       ------------------------------ 124.46 KiB/497.29 KiB
# huggingface-hub ------------------------------ 399.11 KiB/545.69 KiB
# greenlet   ------------------------------ 477.68 KiB/571.78 KiB
# chromadb   ------------------------------ 414.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 110.92 KiB/634.88 KiB
# pyvis      ------------------------------ 557.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 541.64 KiB/745.07 KiB
# openai     ------------------------------ 158.66 KiB/746.46 KiB
# regex      ------------------------------ 494.69 KiB/774.15 KiB
# ipython    ------------------------------ 393.67 KiB/812.37 KiB
# langchain  ------------------------------ 46.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 504.56 KiB/1.14 MiB
# pygments   ------------------------------ 478.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# tzdata     ------------------------------ 16.00 KiB/339.69 KiB
# yarl       ------------------------------ 48.00 KiB/340.80 KiB
# jiter      ------------------------------ 52.02 KiB/343.92 KiB
# langsmith  ------------------------------ 127.89 KiB/354.49 KiB
# crewai     ------------------------------ 142.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 142.88 KiB/378.72 KiB
# langchain-core ------------------------------ 206.88 KiB/432.43 KiB
# pytz       ------------------------------ 124.46 KiB/497.29 KiB
# huggingface-hub ------------------------------ 415.11 KiB/545.69 KiB
# greenlet   ------------------------------ 477.68 KiB/571.78 KiB
# chromadb   ------------------------------ 414.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 142.92 KiB/634.88 KiB
# pyvis      ------------------------------ 573.56 KiB/738.32 KiB
# pyyaml     ------------------------------ 557.64 KiB/745.07 KiB
# openai     ------------------------------ 174.66 KiB/746.46 KiB
# regex      ------------------------------ 526.69 KiB/774.15 KiB
# ipython    ------------------------------ 415.17 KiB/812.37 KiB
# langchain  ------------------------------ 46.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 536.56 KiB/1.14 MiB
# pygments   ------------------------------ 510.12 KiB/1.17 MiB
# jedi       ------------------------------ 244.15 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# protobuf   ------------------------------ 15.89 KiB/313.54 KiB
# qdrant-client ------------------------------ 32.00 KiB/329.36 KiB
# tzdata     ------------------------------ 16.00 KiB/339.69 KiB
# yarl       ------------------------------ 94.52 KiB/340.80 KiB
# jiter      ------------------------------ 80.00 KiB/343.92 KiB
# langsmith  ------------------------------ 160.00 KiB/354.49 KiB
# crewai     ------------------------------ 158.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 190.88 KiB/378.72 KiB
# langchain-core ------------------------------ 286.88 KiB/432.43 KiB
# pytz       ------------------------------ 124.46 KiB/497.29 KiB
# huggingface-hub ------------------------------ 431.11 KiB/545.69 KiB
# greenlet   ------------------------------ 541.68 KiB/571.78 KiB
# chromadb   ------------------------------ 446.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 158.92 KiB/634.88 KiB
# pyvis      ------------------------------ 606.00 KiB/738.32 KiB
# pyyaml     ------------------------------ 595.72 KiB/745.07 KiB
# openai     ------------------------------ 222.66 KiB/746.46 KiB
# regex      ------------------------------ 558.69 KiB/774.15 KiB
# ipython    ------------------------------ 463.17 KiB/812.37 KiB
# langchain  ------------------------------ 62.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 558.74 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# protobuf   ------------------------------ 108.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 107.76 KiB/329.36 KiB
# tzdata     ------------------------------ 75.54 KiB/339.69 KiB
# yarl       ------------------------------ 190.41 KiB/340.80 KiB
# jiter      ------------------------------ 192.00 KiB/343.92 KiB
# langsmith  ------------------------------ 249.57 KiB/354.49 KiB
# crewai     ------------------------------ 190.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 270.88 KiB/378.72 KiB
# langchain-core ------------------------------ 350.88 KiB/432.43 KiB
# pytz       ------------------------------ 140.46 KiB/497.29 KiB
# huggingface-hub ------------------------------ 495.11 KiB/545.69 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 536.74 KiB/634.88 KiB
# pyvis      ------------------------------ 716.93 KiB/738.32 KiB
# pyyaml     ------------------------------ 669.64 KiB/745.07 KiB
# openai     ------------------------------ 254.66 KiB/746.46 KiB
# regex      ------------------------------ 670.69 KiB/774.15 KiB
# ipython    ------------------------------ 511.17 KiB/812.37 KiB
# langchain  ------------------------------ 78.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 648.56 KiB/1.14 MiB
# pygments   ------------------------------ 638.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠹ Preparing packages... (0/204)
# protobuf   ------------------------------ 108.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 107.76 KiB/329.36 KiB
# tzdata     ------------------------------ 75.54 KiB/339.69 KiB
# yarl       ------------------------------ 190.52 KiB/340.80 KiB
# jiter      ------------------------------ 192.00 KiB/343.92 KiB
# langsmith  ------------------------------ 249.57 KiB/354.49 KiB
# crewai     ------------------------------ 190.92 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 270.88 KiB/378.72 KiB
# langchain-core ------------------------------ 350.88 KiB/432.43 KiB
# pytz       ------------------------------ 140.46 KiB/497.29 KiB
# huggingface-hub ------------------------------ 495.11 KiB/545.69 KiB
# chromadb   ------------------------------ 478.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 536.74 KiB/634.88 KiB
# pyvis      ------------------------------ 716.93 KiB/738.32 KiB
# pyyaml     ------------------------------ 669.64 KiB/745.07 KiB
# openai     ------------------------------ 254.66 KiB/746.46 KiB
# regex      ------------------------------ 670.69 KiB/774.15 KiB
# ipython    ------------------------------ 511.17 KiB/812.37 KiB
# langchain  ------------------------------ 78.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 648.56 KiB/1.14 MiB
# pygments   ------------------------------ 654.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# pypdf      ------------------------------ 16.00 KiB/302.46 KiB
# protobuf   ------------------------------ 156.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 159.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 219.75 KiB/340.80 KiB
# jiter      ------------------------------ 255.94 KiB/343.92 KiB
# langsmith  ------------------------------ 304.00 KiB/354.49 KiB
# crewai     ------------------------------ 198.96 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 302.88 KiB/378.72 KiB
# langchain-core ------------------------------ 382.88 KiB/432.43 KiB
# pytz       ------------------------------ 156.46 KiB/497.29 KiB
# huggingface-hub ------------------------------ 527.11 KiB/545.69 KiB
# chromadb   ------------------------------ 494.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 552.74 KiB/634.88 KiB
# pyyaml     ------------------------------ 733.54 KiB/745.07 KiB
# openai     ------------------------------ 286.66 KiB/746.46 KiB
# regex      ------------------------------ 734.69 KiB/774.15 KiB
# ipython    ------------------------------ 580.59 KiB/812.37 KiB
# langchain  ------------------------------ 78.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 693.70 KiB/1.14 MiB
# pygments   ------------------------------ 750.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# pypdf      ------------------------------ 32.00 KiB/302.46 KiB
# protobuf   ------------------------------ 172.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 159.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 235.75 KiB/340.80 KiB
# jiter      ------------------------------ 255.94 KiB/343.92 KiB
# langsmith  ------------------------------ 311.10 KiB/354.49 KiB
# crewai     ------------------------------ 214.96 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 318.88 KiB/378.72 KiB
# langchain-core ------------------------------ 382.88 KiB/432.43 KiB
# pytz       ------------------------------ 156.46 KiB/497.29 KiB
# chromadb   ------------------------------ 494.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 552.74 KiB/634.88 KiB
# pyyaml     ------------------------------ 733.64 KiB/745.07 KiB
# openai     ------------------------------ 286.66 KiB/746.46 KiB
# regex      ------------------------------ 734.69 KiB/774.15 KiB
# ipython    ------------------------------ 596.59 KiB/812.37 KiB
# langchain  ------------------------------ 94.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 706.87 KiB/1.14 MiB
# pygments   ------------------------------ 782.12 KiB/1.17 MiB
# jedi       ------------------------------ 271.16 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# googleapis-common-protos ------------------------------     0 B/287.63 KiB
# pypdf      ------------------------------ 48.00 KiB/302.46 KiB
# protobuf   ------------------------------ 188.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 159.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 251.75 KiB/340.80 KiB
# jiter      ------------------------------ 256.00 KiB/343.92 KiB
# langsmith  ------------------------------ 327.10 KiB/354.49 KiB
# crewai     ------------------------------ 214.96 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 334.88 KiB/378.72 KiB
# langchain-core ------------------------------ 408.56 KiB/432.43 KiB
# pytz       ------------------------------ 172.46 KiB/497.29 KiB
# chromadb   ------------------------------ 494.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 552.74 KiB/634.88 KiB
# openai     ------------------------------ 302.66 KiB/746.46 KiB
# regex      ------------------------------ 766.69 KiB/774.15 KiB
# ipython    ------------------------------ 623.17 KiB/812.37 KiB
# langchain  ------------------------------ 94.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 712.56 KiB/1.14 MiB
# pygments   ------------------------------ 798.12 KiB/1.17 MiB
# jedi       ------------------------------ 271.16 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# googleapis-common-protos ------------------------------ 16.00 KiB/287.63 KiB
# pypdf      ------------------------------ 64.00 KiB/302.46 KiB
# protobuf   ------------------------------ 188.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 175.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 254.52 KiB/340.80 KiB
# jiter      ------------------------------ 272.00 KiB/343.92 KiB
# langsmith  ------------------------------ 327.10 KiB/354.49 KiB
# crewai     ------------------------------ 214.96 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 334.88 KiB/378.72 KiB
# langchain-core ------------------------------ 408.56 KiB/432.43 KiB
# pytz       ------------------------------ 172.46 KiB/497.29 KiB
# chromadb   ------------------------------ 494.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 552.74 KiB/634.88 KiB
# openai     ------------------------------ 302.66 KiB/746.46 KiB
# regex      ------------------------------ 766.69 KiB/774.15 KiB
# ipython    ------------------------------ 623.17 KiB/812.37 KiB
# langchain  ------------------------------ 94.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 712.56 KiB/1.14 MiB
# pygments   ------------------------------ 814.12 KiB/1.17 MiB
# jedi       ------------------------------ 271.16 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# anthropic  ------------------------------     0 B/286.19 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/287.63 KiB
# pypdf      ------------------------------ 66.49 KiB/302.46 KiB
# protobuf   ------------------------------ 204.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 191.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 254.52 KiB/340.80 KiB
# jiter      ------------------------------ 272.00 KiB/343.92 KiB
# langsmith  ------------------------------ 336.00 KiB/354.49 KiB
# crewai     ------------------------------ 214.96 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 350.88 KiB/378.72 KiB
# langchain-core ------------------------------ 424.56 KiB/432.43 KiB
# pytz       ------------------------------ 172.46 KiB/497.29 KiB
# chromadb   ------------------------------ 510.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 565.75 KiB/634.88 KiB
# openai     ------------------------------ 302.66 KiB/746.46 KiB
# ipython    ------------------------------ 639.17 KiB/812.37 KiB
# langchain  ------------------------------ 110.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 728.56 KiB/1.14 MiB
# pygments   ------------------------------ 830.12 KiB/1.17 MiB
# jedi       ------------------------------ 271.16 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# cohere     ------------------------------     0 B/285.05 KiB
# anthropic  ------------------------------ 12.60 KiB/286.19 KiB
# googleapis-common-protos ------------------------------ 16.00 KiB/287.63 KiB
# pypdf      ------------------------------ 66.49 KiB/302.46 KiB
# protobuf   ------------------------------ 204.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 191.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 270.52 KiB/340.80 KiB
# jiter      ------------------------------ 288.00 KiB/343.92 KiB
# langsmith  ------------------------------ 336.00 KiB/354.49 KiB
# crewai     ------------------------------ 214.96 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 350.88 KiB/378.72 KiB
# pytz       ------------------------------ 172.46 KiB/497.29 KiB
# chromadb   ------------------------------ 510.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 565.75 KiB/634.88 KiB
# openai     ------------------------------ 302.66 KiB/746.46 KiB
# ipython    ------------------------------ 639.17 KiB/812.37 KiB
# langchain  ------------------------------ 110.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 728.56 KiB/1.14 MiB
# pygments   ------------------------------ 830.12 KiB/1.17 MiB
# jedi       ------------------------------ 271.16 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# openpyxl   ------------------------------     0 B/245.03 KiB
# bcrypt     ------------------------------ 16.00 KiB/277.50 KiB
# cohere     ------------------------------ 32.00 KiB/285.05 KiB
# anthropic  ------------------------------ 28.60 KiB/286.19 KiB
# googleapis-common-protos ------------------------------ 32.00 KiB/287.63 KiB
# pypdf      ------------------------------ 96.00 KiB/302.46 KiB
# protobuf   ------------------------------ 252.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 207.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 302.41 KiB/340.80 KiB
# jiter      ------------------------------ 309.73 KiB/343.92 KiB
# crewai     ------------------------------ 230.96 KiB/357.76 KiB
# prompt-toolkit ------------------------------ 366.88 KiB/378.72 KiB
# pytz       ------------------------------ 172.46 KiB/497.29 KiB
# chromadb   ------------------------------ 542.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 568.88 KiB/634.88 KiB
# openai     ------------------------------ 302.66 KiB/746.46 KiB
# ipython    ------------------------------ 639.17 KiB/812.37 KiB
# langchain  ------------------------------ 110.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 760.56 KiB/1.14 MiB
# pygments   ------------------------------ 862.01 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# openpyxl   ------------------------------     0 B/245.03 KiB
# bcrypt     ------------------------------ 16.00 KiB/277.50 KiB
# cohere     ------------------------------ 32.00 KiB/285.05 KiB
# anthropic  ------------------------------ 44.60 KiB/286.19 KiB
# googleapis-common-protos ------------------------------ 32.00 KiB/287.63 KiB
# pypdf      ------------------------------ 96.00 KiB/302.46 KiB
# protobuf   ------------------------------ 252.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 223.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 302.41 KiB/340.80 KiB
# jiter      ------------------------------ 309.73 KiB/343.92 KiB
# crewai     ------------------------------ 230.96 KiB/357.76 KiB
# pytz       ------------------------------ 172.46 KiB/497.29 KiB
# chromadb   ------------------------------ 542.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 584.74 KiB/634.88 KiB
# openai     ------------------------------ 318.66 KiB/746.46 KiB
# ipython    ------------------------------ 655.17 KiB/812.37 KiB
# langchain  ------------------------------ 126.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 760.56 KiB/1.14 MiB
# pygments   ------------------------------ 862.01 KiB/1.17 MiB
# jedi       ------------------------------ 271.16 KiB/1.50 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# multidict  ------------------------------ 16.00 KiB/240.83 KiB
# alembic    ------------------------------ 14.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# bcrypt     ------------------------------ 61.80 KiB/277.50 KiB
# cohere     ------------------------------ 48.00 KiB/285.05 KiB
# anthropic  ------------------------------ 60.60 KiB/286.19 KiB
# googleapis-common-protos ------------------------------ 50.17 KiB/287.63 KiB
# pypdf      ------------------------------ 128.00 KiB/302.46 KiB
# protobuf   ------------------------------ 263.19 KiB/313.54 KiB
# qdrant-client ------------------------------ 255.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 325.56 KiB/340.80 KiB
# jiter      ------------------------------ 343.92 KiB/343.92 KiB
# crewai     ------------------------------ 230.96 KiB/357.76 KiB
# pytz       ------------------------------ 188.46 KiB/497.29 KiB
# chromadb   ------------------------------ 558.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 601.31 KiB/634.88 KiB
# openai     ------------------------------ 318.66 KiB/746.46 KiB
# ipython    ------------------------------ 671.17 KiB/812.37 KiB
# langchain  ------------------------------ 126.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 808.56 KiB/1.14 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# multidict  ------------------------------ 16.00 KiB/240.83 KiB
# alembic    ------------------------------ 14.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# bcrypt     ------------------------------ 61.80 KiB/277.50 KiB
# cohere     ------------------------------ 48.00 KiB/285.05 KiB
# anthropic  ------------------------------ 60.60 KiB/286.19 KiB
# googleapis-common-protos ------------------------------ 50.17 KiB/287.63 KiB
# pypdf      ------------------------------ 128.00 KiB/302.46 KiB
# protobuf   ------------------------------ 263.19 KiB/313.54 KiB
# qdrant-client ------------------------------ 255.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# yarl       ------------------------------ 334.52 KiB/340.80 KiB
# crewai     ------------------------------ 230.96 KiB/357.76 KiB
# pytz       ------------------------------ 188.46 KiB/497.29 KiB
# chromadb   ------------------------------ 558.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 601.31 KiB/634.88 KiB
# openai     ------------------------------ 318.66 KiB/746.46 KiB
# ipython    ------------------------------ 671.17 KiB/812.37 KiB
# langchain  ------------------------------ 126.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 824.56 KiB/1.14 MiB
# pygments   ------------------------------ 894.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# rich       ------------------------------     0 B/236.74 KiB
# multidict  ------------------------------ 40.01 KiB/240.83 KiB
# alembic    ------------------------------ 46.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 16.00 KiB/245.03 KiB
# bcrypt     ------------------------------ 93.80 KiB/277.50 KiB
# cohere     ------------------------------ 48.00 KiB/285.05 KiB
# anthropic  ------------------------------ 60.60 KiB/286.19 KiB
# googleapis-common-protos ------------------------------ 60.84 KiB/287.63 KiB
# pypdf      ------------------------------ 176.00 KiB/302.46 KiB
# protobuf   ------------------------------ 284.24 KiB/313.54 KiB
# qdrant-client ------------------------------ 255.41 KiB/329.36 KiB
# tzdata     ------------------------------ 91.43 KiB/339.69 KiB
# crewai     ------------------------------ 246.96 KiB/357.76 KiB
# pytz       ------------------------------ 188.46 KiB/497.29 KiB
# chromadb   ------------------------------ 558.92 KiB/613.62 KiB
# crewai-tools ------------------------------ 601.31 KiB/634.88 KiB
# openai     ------------------------------ 318.66 KiB/746.46 KiB
# ipython    ------------------------------ 687.17 KiB/812.37 KiB
# langchain  ------------------------------ 126.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 840.56 KiB/1.14 MiB
# pygments   ------------------------------ 926.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# tomli      ------------------------------ 32.00 KiB/230.50 KiB
# rich       ------------------------------ 30.92 KiB/236.74 KiB
# multidict  ------------------------------ 77.74 KiB/240.83 KiB
# alembic    ------------------------------ 94.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 32.00 KiB/245.03 KiB
# bcrypt     ------------------------------ 141.80 KiB/277.50 KiB
# cohere     ------------------------------ 79.62 KiB/285.05 KiB
# anthropic  ------------------------------ 76.92 KiB/286.19 KiB
# googleapis-common-protos ------------------------------ 92.84 KiB/287.63 KiB
# pypdf      ------------------------------ 224.00 KiB/302.46 KiB
# protobuf   ------------------------------ 313.54 KiB/313.54 KiB
# qdrant-client ------------------------------ 317.96 KiB/329.36 KiB
# tzdata     ------------------------------ 107.43 KiB/339.69 KiB
# crewai     ------------------------------ 262.96 KiB/357.76 KiB
# pytz       ------------------------------ 204.46 KiB/497.29 KiB
# chromadb   ------------------------------ 574.92 KiB/613.62 KiB
# openai     ------------------------------ 334.66 KiB/746.46 KiB
# ipython    ------------------------------ 703.17 KiB/812.37 KiB
# langchain  ------------------------------ 142.89 KiB/994.33 KiB
# tiktoken   ------------------------------ 904.56 KiB/1.14 MiB
# pygments   ------------------------------ 958.12 KiB/1.17 MiB
# Building new-project @ file:///home/jovyan/work/L13/new_project
# ⠸ Preparing packages... (6/204)
# tomli      ------------------------------ 32.00 KiB/230.50 KiB
# rich       ------------------------------ 46.92 KiB/236.74 KiB
# multidict  ------------------------------ 93.74 KiB/240.83 KiB
# alembic    ------------------------------ 110.89 KiB/241.24 KiB
# openpyxl   ------------------------------ 32.00 KiB/245.03 KiB
# bcrypt     ------------------------------ 157.80 KiB/277.50 KiB
# cohere     ------------------------------ 79.62 KiB/285.05 KiB
# ...
# uv         ------------------------------ 13.80 MiB/17.79 MiB
# lancedb    ------------------------------ 15.96 MiB/33.22 MiB
# pyarrow    ------------------------------ 22.18 MiB/40.84 MiB
# ⠋ Preparing packages... (199/204) 19.92 MiB/43.79 MiB
# numpy      ------------------------------ 14.98 MiB/16.04 MiB
# uv         ------------------------------ 13.80 MiB/17.79 MiB
# lancedb    ------------------------------ 16.51 MiB/33.22 MiB
# pyarrow    ------------------------------ 22.86 MiB/40.84 MiB
# ⠋ Preparing packages... (199/204) 19.93 MiB/43.79 MiB
# numpy      ------------------------------ 14.98 MiB/16.04 MiB
# uv         ------------------------------ 13.80 MiB/17.79 MiB
# lancedb    ------------------------------ 16.51 MiB/33.22 MiB
# pyarrow    ------------------------------ 22.86 MiB/40.84 MiB
# ⠙ Preparing packages... (199/204) 19.94 MiB/43.79 MiB
# numpy      ------------------------------ 14.98 MiB/16.04 MiB
# uv         ------------------------------ 13.80 MiB/17.79 MiB
# lancedb    ------------------------------ 16.51 MiB/33.22 MiB
# pyarrow    ------------------------------ 22.86 MiB/40.84 MiB
# ⠙ Preparing packages... (199/204) 20.52 MiB/43.79 MiB
# numpy      ------------------------------ 14.98 MiB/16.04 MiB
# uv         ------------------------------ 13.80 MiB/17.79 MiB
# lancedb    ------------------------------ 16.54 MiB/33.22 MiB
# pyarrow    ------------------------------ 22.86 MiB/40.84 MiB
# ⠙ Preparing packages... (199/204) 20.52 MiB/43.79 MiB
# numpy      ------------------------------ 14.98 MiB/16.04 MiB
# uv         ------------------------------ 13.80 MiB/17.79 MiB
# lancedb    ------------------------------ 17.39 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.37 MiB/40.84 MiB
# ⠹ Preparing packages... (199/204) 21.00 MiB/43.79 MiB
# numpy      ------------------------------ 14.98 MiB/16.04 MiB
# uv         ------------------------------ 14.16 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠹ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.01 MiB/16.04 MiB
# uv         ------------------------------ 14.16 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠹ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.03 MiB/16.04 MiB
# uv         ------------------------------ 14.16 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠹ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.60 MiB/16.04 MiB
# uv         ------------------------------ 14.16 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# uv         ------------------------------ 14.63 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# uv         ------------------------------ 14.69 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# uv         ------------------------------ 14.71 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# uv         ------------------------------ 14.73 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 22.90 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# uv         ------------------------------ 15.00 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 23.56 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# uv         ------------------------------ 17.63 MiB/17.79 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 26.12 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠸ Preparing packages... (199/204) 30.17 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# lancedb    ------------------------------ 17.81 MiB/33.22 MiB
# pyarrow    ------------------------------ 23.82 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 31.94 MiB/43.79 MiB
# numpy      ------------------------------ 15.80 MiB/16.04 MiB
# lancedb    ------------------------------ 18.57 MiB/33.22 MiB
# pyarrow    ------------------------------ 24.70 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 35.14 MiB/43.79 MiB
# lancedb    ------------------------------ 19.04 MiB/33.22 MiB
# pyarrow    ------------------------------ 25.08 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 35.36 MiB/43.79 MiB
# lancedb    ------------------------------ 19.04 MiB/33.22 MiB
# pyarrow    ------------------------------ 25.08 MiB/40.84 MiB
# ⠼ Preparing packages... (200/204) 35.42 MiB/43.79 MiB
# lancedb    ------------------------------ 19.04 MiB/33.22 MiB
# pyarrow    ------------------------------ 25.08 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 35.43 MiB/43.79 MiB
# lancedb    ------------------------------ 19.84 MiB/33.22 MiB
# pyarrow    ------------------------------ 25.08 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 35.88 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 26.09 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 36.98 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 26.10 MiB/40.84 MiB
# ⠴ Preparing packages... (201/204) 36.98 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 27.46 MiB/40.84 MiB
# ⠦ Preparing packages... (201/204) 36.98 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 27.93 MiB/40.84 MiB
# ⠦ Preparing packages... (201/204) 36.98 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 28.93 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 36.98 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 30.27 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 37.33 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 30.31 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 37.33 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 30.33 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 37.33 MiB/43.79 MiB
# lancedb    ------------------------------ 20.17 MiB/33.22 MiB
# pyarrow    ------------------------------ 30.34 MiB/40.84 MiB
# ⠧ Preparing packages... (201/204) 37.33 MiB/43.79 MiB
# lancedb    ------------------------------ 21.61 MiB/33.22 MiB
# pyarrow    ------------------------------ 31.30 MiB/40.84 MiB
# ⠇ Preparing packages... (201/204) 38.84 MiB/43.79 MiB
# lancedb    ------------------------------ 23.73 MiB/33.22 MiB
# pyarrow    ------------------------------ 31.63 MiB/40.84 MiB
# ⠇ Preparing packages... (201/204) 38.84 MiB/43.79 MiB
# lancedb    ------------------------------ 23.73 MiB/33.22 MiB
# pyarrow    ------------------------------ 31.65 MiB/40.84 MiB
# ⠇ Preparing packages... (201/204) 38.84 MiB/43.79 MiB
# lancedb    ------------------------------ 23.73 MiB/33.22 MiB
# pyarrow    ------------------------------ 31.66 MiB/40.84 MiB
# ⠇ Preparing packages... (201/204) 38.84 MiB/43.79 MiB
# lancedb    ------------------------------ 23.73 MiB/33.22 MiB
# pyarrow    ------------------------------ 32.34 MiB/40.84 MiB
# ⠇ Preparing packages... (201/204) 38.84 MiB/43.79 MiB
# lancedb    ------------------------------ 24.44 MiB/33.22 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 38.84 MiB/43.79 MiB
# lancedb    ------------------------------ 25.92 MiB/33.22 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 39.37 MiB/43.79 MiB
# lancedb    ------------------------------ 25.92 MiB/33.22 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 39.45 MiB/43.79 MiB
# lancedb    ------------------------------ 25.92 MiB/33.22 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 39.45 MiB/43.79 MiB
# lancedb    ------------------------------ 25.92 MiB/33.22 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠋ Preparing packages... (201/204) 39.47 MiB/43.79 MiB
# lancedb    ------------------------------ 26.67 MiB/33.22 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠙ Preparing packages... (201/204) 41.27 MiB/43.79 MiB
# lancedb    ------------------------------ 32.00 MiB/33.22 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠙ Preparing packages... (201/204) 41.59 MiB/43.79 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠙ Preparing packages... (201/204) 41.62 MiB/43.79 MiB
# pyarrow    ------------------------------ 33.71 MiB/40.84 MiB
# ⠙ Preparing packages... (201/204) 42.87 MiB/43.79 MiB
# ⠙ Preparing packages... (201/204) 33.71 MiB/40.84 MiB
# ⠹ Preparing packages... (203/204) 34.11 MiB/40.84 MiB
# ⠹ Preparing packages... (203/204) 37.00 MiB/40.84 MiB
# ⠹ Preparing packages... (203/204) 39.34 MiB/40.84 MiB
# Prepared 204 packages in 7.50s
# Installed 204 packages in 194ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.12.14
#  + aiosignal==1.4.0
#  + alembic==1.16.4
#  + annotated-types==0.7.0
#  + anthropic==0.59.0
#  + anyio==4.9.0
#  + appdirs==1.4.4
#  + asgiref==3.9.1
#  + asttokens==3.0.0
#  + attrs==25.3.0
#  + backoff==2.2.1
#  + bcrypt==4.3.0
#  + beautifulsoup4==4.13.4
#  + blinker==1.9.0
#  + browserbase==1.4.0
#  + build==1.2.2.post1
#  + cachetools==5.5.2
#  + certifi==2025.7.14
#  + cffi==1.17.1
#  + charset-normalizer==3.4.2
#  + chroma-hnswlib==0.7.6
#  + chromadb==0.5.23
#  + click==8.2.1
#  + cohere==5.16.1
#  + coloredlogs==15.0.1
#  + crewai==0.150.0
#  + crewai-tools==0.58.0
#  + cryptography==45.0.5
#  + dataclasses-json==0.6.7
#  + decorator==5.2.1
#  + deprecation==2.1.0
#  + diskcache==5.6.3
#  + distro==1.9.0
#  + docker==7.1.0
#  + docstring-parser==0.17.0
#  + durationpy==0.10
#  + embedchain==0.1.128
#  + et-xmlfile==2.0.0
#  + executing==2.2.0
#  + fastapi==0.116.1
#  + fastavro==1.11.1
#  + filelock==3.18.0
#  + flatbuffers==25.2.10
#  + frozenlist==1.7.0
#  + fsspec==2025.7.0
#  + google-auth==2.40.3
#  + googleapis-common-protos==1.70.0
#  + gptcache==0.1.44
#  + greenlet==3.2.3
#  + grpcio==1.74.0
#  + h11==0.16.0
#  + h2==4.2.0
#  + hf-xet==1.1.5
#  + hpack==4.1.0
#  + httpcore==1.0.9
#  + httptools==0.6.4
#  + httpx==0.28.1
#  + httpx-sse==0.4.0
#  + huggingface-hub==0.34.1
#  + humanfriendly==10.0
#  + hyperframe==6.1.0
#  + idna==3.10
#  + importlib-metadata==8.7.0
#  + importlib-resources==6.5.2
#  + instructor==1.10.0
#  + ipython==8.37.0
#  + jedi==0.19.2
#  + jinja2==3.1.6
#  + jiter==0.10.0
#  + json-repair==0.25.2
#  + json5==0.12.0
#  + jsonpatch==1.33
#  + jsonpickle==4.1.1
#  + jsonpointer==3.0.0
#  + jsonref==1.1.0
#  + jsonschema==4.25.0
#  + jsonschema-specifications==2025.4.1
#  + kubernetes==33.1.0
#  + lancedb==0.24.2
#  + langchain==0.3.27
#  + langchain-cohere==0.3.5
#  + langchain-community==0.3.27
#  + langchain-core==0.3.72
#  + langchain-experimental==0.3.4
#  + langchain-openai==0.2.14
#  + langchain-text-splitters==0.3.9
#  + langsmith==0.3.45
#  + litellm==1.74.3
#  + mako==1.3.10
#  + markdown-it-py==3.0.0
#  + markupsafe==3.0.2
#  + marshmallow==3.26.1
#  + matplotlib-inline==0.1.7
#  + mdurl==0.1.2
#  + mem0ai==0.1.115
#  + mmh3==5.1.0
#  + monotonic==1.6
#  + mpmath==1.3.0
#  + multidict==6.6.3
#  + mypy-extensions==1.1.0
#  + networkx==3.4.2
#  + new-project==0.1.0 (from file:///home/jovyan/work/L13/new_project)
#  + nodeenv==1.9.1
#  + numpy==2.2.6
#  + oauthlib==3.3.1
#  + onnxruntime==1.22.0
#  + openai==1.97.1
#  + openpyxl==3.1.5
#  + opentelemetry-api==1.35.0
#  + opentelemetry-exporter-otlp-proto-common==1.35.0
#  + opentelemetry-exporter-otlp-proto-grpc==1.35.0
#  + opentelemetry-exporter-otlp-proto-http==1.35.0
#  + opentelemetry-instrumentation==0.56b0
#  + opentelemetry-instrumentation-asgi==0.56b0
#  + opentelemetry-instrumentation-fastapi==0.56b0
#  + opentelemetry-proto==1.35.0
#  + opentelemetry-sdk==1.35.0
#  + opentelemetry-semantic-conventions==0.56b0
#  + opentelemetry-util-http==0.56b0
#  + orjson==3.11.1
#  + overrides==7.7.0
#  + packaging==25.0
#  + pandas==2.3.1
#  + parso==0.8.4
#  + pdfminer-six==20250506
#  + pdfplumber==0.11.7
#  + pexpect==4.9.0
#  + pillow==11.3.0
#  + playwright==1.54.0
#  + portalocker==2.7.0
#  + posthog==3.25.0
#  + prompt-toolkit==3.0.51
#  + propcache==0.3.2
#  + protobuf==6.31.1
#  + ptyprocess==0.7.0
#  + pure-eval==0.2.3
#  + pyarrow==21.0.0
#  + pyasn1==0.6.1
#  + pyasn1-modules==0.4.2
#  + pycparser==2.22
#  + pydantic==2.11.7
#  + pydantic-core==2.33.2
#  + pydantic-settings==2.10.1
#  + pyee==13.0.0
#  + pygments==2.19.2
#  + pyjwt==2.10.1
#  + pypdf==5.8.0
#  + pypdfium2==4.30.0
#  + pypika==0.48.9
#  + pyproject-hooks==1.2.0
#  + pyright==1.1.403
#  + pysbd==0.3.4
#  + python-dateutil==2.9.0.post0
#  + python-dotenv==1.1.1
#  + pytube==15.0.0
#  + pytz==2025.2
#  + pyvis==0.3.2
#  + pyyaml==6.0.2
#  + qdrant-client==1.15.0
#  + referencing==0.36.2
#  + regex==2024.11.6
#  + requests==2.32.4
#  + requests-oauthlib==2.0.0
#  + requests-toolbelt==1.0.0
#  + rich==13.9.4
#  + rpds-py==0.26.0
#  + rsa==4.9.1
#  + schema==0.7.7
#  + shellingham==1.5.4
#  + six==1.17.0
#  + sniffio==1.3.1
#  + soupsieve==2.7
#  + sqlalchemy==2.0.41
#  + stack-data==0.6.3
#  + stagehand==0.4.1
#  + starlette==0.47.2
#  + sympy==1.14.0
#  + tabulate==0.9.0
#  + tenacity==9.1.2
#  + tiktoken==0.9.0
#  + tokenizers==0.20.3
#  + tomli==2.2.1
#  + tomli-w==1.2.0
#  + tqdm==4.67.1
#  + traitlets==5.14.3
#  + typer==0.16.0
#  + types-requests==2.32.4.20250611
#  + typing-extensions==4.14.1
#  + typing-inspect==0.9.0
#  + typing-inspection==0.4.1
#  + tzdata==2025.2
#  + urllib3==2.5.0
#  + uv==0.8.3
#  + uvicorn==0.35.0
#  + uvloop==0.21.0
#  + watchfiles==1.1.0
#  + wcwidth==0.2.13
#  + websocket-client==1.8.0
#  + websockets==15.0.1
#  + wrapt==1.17.2
#  + yarl==1.20.1
#  + zipp==3.23.0
#  + zstandard==0.23.0

# %% [markdown]
# ## Setting Environment Variables

# %%
! cat new_project/.env
# Out:
# OPENAI_API_KEY=YOUR_API_KEY_HERE

# %% [markdown]
# ## Running the Crew

# %%
! cd new_project && crewai run
# Out:
# Running the Crew
# ╭─────────────────────────── Crew Execution Started ───────────────────────────╮
# │                                                                              │
# │  Crew Execution Started                                                      │
# │  Name: crew                                                                  │
# │  ID: 4d1ab99d-a9b9-4889-8f9b-6f9ff90e841d                                    │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Task: Conduct a thorough research about AI LLMs Make sure you find any      │
# │  interesting and relevant information given the current year is 2024.        │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
# 🚀 Crew: crew
# └── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Final Answer:                                                               │
# │  1. **Emergence of Multimodal Models**: In 2024, the development of          │
# │  multimodal models capable of processing text, images, and audio             │
# │  simultaneously has significantly advanced, leading to enhanced interaction  │
# │  capabilities and richer content generation.                                 │
# │                                                                              │
# │  2. **Increased Context Length**: New LLMs now support longer context        │
# │  lengths, with some models allowing for thousands of tokens of input. This   │
# │  improvement enables more complex conversations and better retention of      │
# │  context over extended interactions.                                         │
# │                                                                              │
# │  3. **Efficiency Optimizations**: Recent techniques, such as quantization    │
# │  and pruning, have drastically improved the efficiency of LLMs, allowing     │
# │  them to run on less powerful hardware without significantly sacrificing     │
# │  performance, which broadens accessibility for developers.                   │
# │                                                                              │
# │  4. **Integration of External Knowledge Bases**: Many contemporary LLMs are  │
# │  now designed to seamlessly integrate with external databases and knowledge  │
# │  sources, enabling more accurate and up-to-date information retrieval and    │
# │  response generation.                                                        │
# │                                                                              │
# │  5. **Personalized AI Assistants**: Advancements in personalization          │
# │  algorithms have allowed LLM-based applications to offer highly tailored     │
# │  responses that take into account user preferences, past interactions, and   │
# │  contextual relevance.                                                       │
# │                                                                              │
# │  6. **Regulatory and Ethical Considerations**: The AI landscape has seen     │
# │  growing attention toward ethical frameworks and regulatory measures. In     │
# │  2024, several organizations are prioritizing responsible AI use, impacting  │
# │  how LLMs are developed and deployed.                                        │
# │                                                                              │
# │  7. **Real-time Language Translation**: AI LLMs have made strides in         │
# │  real-time translation capabilities, allowing for instantaneous language     │
# │  processing that facilitates communication across linguistic barriers,       │
# │  beneficial for global collaboration.                                        │
# │                                                                              │
# │  8. **Generative Use Cases in Various Industries**: LLMs have increasingly   │
# │  been adopted across industries, ranging from entertainment, where they      │
# │  assist in scriptwriting, to healthcare, where they help generate patient    │
# │  documentation and summaries.                                                │
# │                                                                              │
# │  9. **Focus on Explainability**: As LLMs become more ubiquitous, there is a  │
# │  strong push toward making them more interpretable. Research is ongoing to   │
# │  enhance users' understanding of how LLMs arrive at specific outputs,        │
# │  addressing transparency concerns.                                           │
# │                                                                              │
# │  10. **Emerging Competition Among Frameworks**: The LLM space is becoming    │
# │  increasingly competitive with major tech companies, startups, and           │
# │  open-source communities contributing diverse models and frameworks,         │
# │  leading to rapid innovation and a rich ecosystem of tools for developers.   │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# └── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
#     Assigned to: AI LLMs Senior Data Researcher
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 2f60c025-686b-4529-81f4-da93e94bfeec                                  │
# │  Agent: AI LLMs Senior Data Researcher                                       │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 4f811817-0c99-4763-81bf-ce37369f0b3a
#     Status: Executing Task...
# ╭────────────────────────────── 🤖 Agent Started ──────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Task: Review the context you got and expand each topic into a full section  │
# │  for a report. Make sure the report is detailed and contains any and all     │
# │  relevant information.                                                       │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
# 🚀 Crew: crew
# ├── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 4f811817-0c99-4763-81bf-ce37369f0b3a
# 🚀 Crew: crew
# ├── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 4f811817-0c99-4763-81bf-ce37369f0b3a
#     Status: Executing Task...
# ╭─────────────────────────── ✅ Agent Final Answer ────────────────────────────╮
# │                                                                              │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Final Answer:                                                               │
# │  # Comprehensive Report on AI LLM Developments in 2024                       │
# │                                                                              │
# │  ## 1. Emergence of Multimodal Models                                        │
# │  In 2024, the landscape of artificial intelligence has been marked by the    │
# │  emergence of multimodal models, which are capable of processing text,       │
# │  images, and audio simultaneously. This advancement has transformed how      │
# │  interactions occur, allowing for richer content generation and more         │
# │  dynamic exchanges between users and AI systems. These models harness the    │
# │  capability to interpret various data forms concurrently, thus facilitating  │
# │  enhanced user engagement and enabling applications such as interactive      │
# │  storytelling, video game development, and augmented reality experiences.    │
# │  Their ability to blend different types of media not only enhances the       │
# │  quality of interactions but also opens up new avenues for creative          │
# │  expression and functional applications.                                     │
# │                                                                              │
# │  ## 2. Increased Context Length                                              │
# │  The advent of new large language models (LLMs) has brought significant      │
# │  improvements in context length, with some architectures supporting          │
# │  thousands of tokens for input. This extension empowers LLMs to maintain     │
# │  more complex conversations and enhances their capacity for sustaining       │
# │  coherent and relevant dialogues over extended interactions. Practically,    │
# │  this translates into improved user experiences in applications like         │
# │  virtual assistants, customer service bots, and educational tools, which     │
# │  are now able to remember and reference prior parts of the conversation      │
# │  more effectively. The ability to process larger context inputs also         │
# │  minimizes misunderstandings and allows for deeper contextual analysis,      │
# │  making the interaction feel more human-like and intuitive.                  │
# │                                                                              │
# │  ## 3. Efficiency Optimizations                                              │
# │  Recent developments in efficiency optimizations—such as quantization and    │
# │  pruning—play a crucial role in enhancing the performance of LLMs on less    │
# │  powerful hardware. These techniques have made it possible for models to     │
# │  run efficiently while retaining high-quality output, broadening             │
# │  accessibility for developers and organizations that may lack extensive      │
# │  computational resources. The reduction in resource requirements is          │
# │  critical for applications in various fields, enabling small businesses and  │
# │  startups to leverage advanced AI capabilities without significant           │
# │  investment in infrastructure. Additionally, such improvements foster        │
# │  innovation, allowing more players in the AI ecosystem to experiment,        │
# │  iterate, and contribute to advancements in the technology.                  │
# │                                                                              │
# │  ## 4. Integration of External Knowledge Bases                               │
# │  One of the notable trends in contemporary LLMs is their seamless            │
# │  integration with external knowledge bases. By allowing models to access a   │
# │  wide array of databases and information sources, these systems can          │
# │  generate responses that are more accurate, informative, and up-to-date.     │
# │  This capability is particularly significant in industries such as finance,  │
# │  healthcare, and education, where timely and precise information is          │
# │  paramount. The integration of external knowledge not only enhances the      │
# │  competency of LLMs in their responses but also helps mitigate the risks     │
# │  associated with misinformation, ensuring users receive authentic content    │
# │  tailored to their inquiries.                                                │
# │                                                                              │
# │  ## 5. Personalized AI Assistants                                            │
# │  The rise of personalized AI assistants is one of the standout achievements  │
# │  in AI development, bolstered by advancements in personalization             │
# │  algorithms. These algorithms allow LLM-based applications to provide        │
# │  highly tailored responses based on user preferences, past interactions,     │
# │  and contextual relevance. Personalization enriches user experience by       │
# │  ensuring that interactions feel more relevant and engaging, which can lead  │
# │  to increased user satisfaction and retention. Applications in this space    │
# │  include smart personal assistants that adapt over time to users' unique     │
# │  needs, preferences in media consumption, and learning methodologies in      │
# │  education.                                                                  │
# │                                                                              │
# │  ## 6. Regulatory and Ethical Considerations                                 │
# │  As AI technologies progress, so does the focus on ethical frameworks and    │
# │  regulatory measures governing their use. In 2024, a significant shift has   │
# │  been seen with various organizations prioritizing responsible AI            │
# │  deployment, highlighting the importance of accountability in AI             │
# │  development. This increased scrutiny translates into a multitude of         │
# │  initiatives aimed at ensuring that LLMs are developed and utilized          │
# │  ethically, considering aspects such as bias prevention, privacy, and data   │
# │  integrity. Ensuring compliance with emerging regulations is not only        │
# │  necessary for legal adherence but also essential for maintaining public     │
# │  trust in AI technologies.                                                   │
# │                                                                              │
# │  ## 7. Real-time Language Translation                                        │
# │  AI LLMs have made substantial strides in real-time language translation,    │
# │  facilitating instantaneous communication across linguistic barriers. This   │
# │  feature is immensely beneficial for global collaboration, allowing          │
# │  businesses and individuals to communicate effectively regardless of         │
# │  language differences. Moreover, improvements in translation accuracy and    │
# │  contextual understanding provide a strong foundation for industries like    │
# │  travel, international relations, and multicultural marketing. The ability   │
# │  to engage in real-time conversations without linguistic limitations         │
# │  further promotes inclusivity and enhances cross-cultural interactions.      │
# │                                                                              │
# │  ## 8. Generative Use Cases in Various Industries                            │
# │  The versatility of LLMs has led to widespread adoption across multiple      │
# │  industries. In entertainment, LLMs aid in scriptwriting and content         │
# │  generation, while in healthcare, they are employed to generate patient      │
# │  documentation, summaries, and diagnostic tools. These applications          │
# │  exemplify the transformative potential of AI technologies in streamlining   │
# │  workflows, enhancing productivity, and generating content that meets        │
# │  industry-specific needs. As various sectors recognize the unique            │
# │  capabilities of LLMs, the trend of generative use cases is expected to      │
# │  expand, continuously reshaping workflows and operational efficiency.        │
# │                                                                              │
# │  ## 9. Focus on Explainability                                               │
# │  With the increasing ubiquity of LLMs, there is a growing demand for         │
# │  explainability in AI processes. Users and stakeholders seek to understand   │
# │  how these models derive specific outputs, which has led to ongoing          │
# │  research focused on enhancing interpretability. This focus aims to address  │
# │  transparency concerns, enabling users to gain insights into the             │
# │  decision-making processes of AI systems. By improving explainability,       │
# │  developers can foster a greater degree of trust in their products and help  │
# │  mitigate the risks of unintended biases in AI outputs. Understanding the    │
# │  rationale behind AI decisions is critical for the adoption and alignment    │
# │  of AI technologies with ethical standards.                                  │
# │                                                                              │
# │  ## 10. Emerging Competition Among Frameworks                                │
# │  The competitive landscape of LLM frameworks has become increasingly         │
# │  diverse, with significant contributions from major tech companies,          │
# │  emerging startups, and open-source communities. This vibrant ecosystem has  │
# │  catalyzed rapid innovation and offered developers a wealth of tools and     │
# │  resources to experiment with. The variety of models and approaches          │
# │  contributes to the acceleration of advancements in the field, allowing for  │
# │  solutions tailored to specific needs and contexts. Furthermore, this        │
# │  competition drives performance improvements and fosters collaboration,      │
# │  ultimately benefiting the broader ecosystem by pushing the boundaries of    │
# │  what is achievable with LLM technologies.                                   │
# │                                                                              │
# │  In conclusion, the advancements in AI LLMs throughout 2024 highlight        │
# │  significant trends and capabilities that not only enhance user interaction  │
# │  but also streamline processes across various industries. The ongoing        │
# │  evolution of these models presents opportunities for further exploration,   │
# │  innovation, and ethical considerations that will define the future          │
# │  trajectories of AI development.                                             │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# 🚀 Crew: crew
# ├── 📋 Task: 2f60c025-686b-4529-81f4-da93e94bfeec
# │   Assigned to: AI LLMs Senior Data Researcher
# │
# │   Status: ✅ Completed
# └── 📋 Task: 4f811817-0c99-4763-81bf-ce37369f0b3a
#     Assigned to: AI LLMs Reporting Analyst
#
#     Status: ✅ Completed
# ╭────────────────────────────── Task Completion ───────────────────────────────╮
# │                                                                              │
# │  Task Completed                                                              │
# │  Name: 4f811817-0c99-4763-81bf-ce37369f0b3a                                  │
# │  Agent: AI LLMs Reporting Analyst                                            │
# │                                                                              │
# │  Tool Args:                                                                  │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯
#
# ╭────────────────────────────── Crew Completion ───────────────────────────────╮
# │                                                                              │
# │  Crew Execution Completed                                                    │
# │  Name: crew                                                                  │
# │  ID: 4d1ab99d-a9b9-4889-8f9b-6f9ff90e841d                                    │
# │  Tool Args:                                                                  │
# │  Final Output: # Comprehensive Report on AI LLM Developments in 2024         │
# │                                                                              │
# │  ## 1. Emergence of Multimodal Models                                        │
# │  In 2024, the landscape of artificial intelligence has been marked by the    │
# │  emergence of multimodal models, which are capable of processing text,       │
# │  images, and audio simultaneously. This advancement has transformed how      │
# │  interactions occur, allowing for richer content generation and more         │
# │  dynamic exchanges between users and AI systems. These models harness the    │
# │  capability to interpret various data forms concurrently, thus facilitating  │
# │  enhanced user engagement and enabling applications such as interactive      │
# │  storytelling, video game development, and augmented reality experiences.    │
# │  Their ability to blend different types of media not only enhances the       │
# │  quality of interactions but also opens up new avenues for creative          │
# │  expression and functional applications.                                     │
# │                                                                              │
# │  ## 2. Increased Context Length                                              │
# │  The advent of new large language models (LLMs) has brought significant      │
# │  improvements in context length, with some architectures supporting          │
# │  thousands of tokens for input. This extension empowers LLMs to maintain     │
# │  more complex conversations and enhances their capacity for sustaining       │
# │  coherent and relevant dialogues over extended interactions. Practically,    │
# │  this translates into improved user experiences in applications like         │
# │  virtual assistants, customer service bots, and educational tools, which     │
# │  are now able to remember and reference prior parts of the conversation      │
# │  more effectively. The ability to process larger context inputs also         │
# │  minimizes misunderstandings and allows for deeper contextual analysis,      │
# │  making the interaction feel more human-like and intuitive.                  │
# │                                                                              │
# │  ## 3. Efficiency Optimizations                                              │
# │  Recent developments in efficiency optimizations—such as quantization and    │
# │  pruning—play a crucial role in enhancing the performance of LLMs on less    │
# │  powerful hardware. These techniques have made it possible for models to     │
# │  run efficiently while retaining high-quality output, broadening             │
# │  accessibility for developers and organizations that may lack extensive      │
# │  computational resources. The reduction in resource requirements is          │
# │  critical for applications in various fields, enabling small businesses and  │
# │  startups to leverage advanced AI capabilities without significant           │
# │  investment in infrastructure. Additionally, such improvements foster        │
# │  innovation, allowing more players in the AI ecosystem to experiment,        │
# │  iterate, and contribute to advancements in the technology.                  │
# │                                                                              │
# │  ## 4. Integration of External Knowledge Bases                               │
# │  One of the notable trends in contemporary LLMs is their seamless            │
# │  integration with external knowledge bases. By allowing models to access a   │
# │  wide array of databases and information sources, these systems can          │
# │  generate responses that are more accurate, informative, and up-to-date.     │
# │  This capability is particularly significant in industries such as finance,  │
# │  healthcare, and education, where timely and precise information is          │
# │  paramount. The integration of external knowledge not only enhances the      │
# │  competency of LLMs in their responses but also helps mitigate the risks     │
# │  associated with misinformation, ensuring users receive authentic content    │
# │  tailored to their inquiries.                                                │
# │                                                                              │
# │  ## 5. Personalized AI Assistants                                            │
# │  The rise of personalized AI assistants is one of the standout achievements  │
# │  in AI development, bolstered by advancements in personalization             │
# │  algorithms. These algorithms allow LLM-based applications to provide        │
# │  highly tailored responses based on user preferences, past interactions,     │
# │  and contextual relevance. Personalization enriches user experience by       │
# │  ensuring that interactions feel more relevant and engaging, which can lead  │
# │  to increased user satisfaction and retention. Applications in this space    │
# │  include smart personal assistants that adapt over time to users' unique     │
# │  needs, preferences in media consumption, and learning methodologies in      │
# │  education.                                                                  │
# │                                                                              │
# │  ## 6. Regulatory and Ethical Considerations                                 │
# │  As AI technologies progress, so does the focus on ethical frameworks and    │
# │  regulatory measures governing their use. In 2024, a significant shift has   │
# │  been seen with various organizations prioritizing responsible AI            │
# │  deployment, highlighting the importance of accountability in AI             │
# │  development. This increased scrutiny translates into a multitude of         │
# │  initiatives aimed at ensuring that LLMs are developed and utilized          │
# │  ethically, considering aspects such as bias prevention, privacy, and data   │
# │  integrity. Ensuring compliance with emerging regulations is not only        │
# │  necessary for legal adherence but also essential for maintaining public     │
# │  trust in AI technologies.                                                   │
# │                                                                              │
# │  ## 7. Real-time Language Translation                                        │
# │  AI LLMs have made substantial strides in real-time language translation,    │
# │  facilitating instantaneous communication across linguistic barriers. This   │
# │  feature is immensely beneficial for global collaboration, allowing          │
# │  businesses and individuals to communicate effectively regardless of         │
# │  language differences. Moreover, improvements in translation accuracy and    │
# │  contextual understanding provide a strong foundation for industries like    │
# │  travel, international relations, and multicultural marketing. The ability   │
# │  to engage in real-time conversations without linguistic limitations         │
# │  further promotes inclusivity and enhances cross-cultural interactions.      │
# │                                                                              │
# │  ## 8. Generative Use Cases in Various Industries                            │
# │  The versatility of LLMs has led to widespread adoption across multiple      │
# │  industries. In entertainment, LLMs aid in scriptwriting and content         │
# │  generation, while in healthcare, they are employed to generate patient      │
# │  documentation, summaries, and diagnostic tools. These applications          │
# │  exemplify the transformative potential of AI technologies in streamlining   │
# │  workflows, enhancing productivity, and generating content that meets        │
# │  industry-specific needs. As various sectors recognize the unique            │
# │  capabilities of LLMs, the trend of generative use cases is expected to      │
# │  expand, continuously reshaping workflows and operational efficiency.        │
# │                                                                              │
# │  ## 9. Focus on Explainability                                               │
# │  With the increasing ubiquity of LLMs, there is a growing demand for         │
# │  explainability in AI processes. Users and stakeholders seek to understand   │
# │  how these models derive specific outputs, which has led to ongoing          │
# │  research focused on enhancing interpretability. This focus aims to address  │
# │  transparency concerns, enabling users to gain insights into the             │
# │  decision-making processes of AI systems. By improving explainability,       │
# │  developers can foster a greater degree of trust in their products and help  │
# │  mitigate the risks of unintended biases in AI outputs. Understanding the    │
# │  rationale behind AI decisions is critical for the adoption and alignment    │
# │  of AI technologies with ethical standards.                                  │
# │                                                                              │
# │  ## 10. Emerging Competition Among Frameworks                                │
# │  The competitive landscape of LLM frameworks has become increasingly         │
# │  diverse, with significant contributions from major tech companies,          │
# │  emerging startups, and open-source communities. This vibrant ecosystem has  │
# │  catalyzed rapid innovation and offered developers a wealth of tools and     │
# │  resources to experiment with. The variety of models and approaches          │
# │  contributes to the acceleration of advancements in the field, allowing for  │
# │  solutions tailored to specific needs and contexts. Furthermore, this        │
# │  competition drives performance improvements and fosters collaboration,      │
# │  ultimately benefiting the broader ecosystem by pushing the boundaries of    │
# │  what is achievable with LLM technologies.                                   │
# │                                                                              │
# │  In conclusion, the advancements in AI LLMs throughout 2024 highlight        │
# │  significant trends and capabilities that not only enhance user interaction  │
# │  but also streamline processes across various industries. The ongoing        │
# │  evolution of these models presents opportunities for further exploration,   │
# │  innovation, and ethical considerations that will define the future          │
# │  trajectories of AI development.                                             │
# │                                                                              │
# │                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────╯

# %% [markdown]
# ## Flows CLI - Command Line Interface

# %%
! crewai create flow new_flow
# Out:
# Creating flow new_flow...
# Flow new_flow created successfully!

# %%
! ls -1 new_flow
# Out:
# README.md
# pyproject.toml
# src
# tests

# %%
! ls -1 new_flow/src/new_flow/
# Out:
# __init__.py
# crews
# main.py
# tools
